# %%
# %matplotlib inline
import os
try:
    from urllib import urlretrieve
except ImportError:
    from urllib.request import urlretrieve
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import ome_files

# %%
fn, _ = urlretrieve("http://downloads.openmicroscopy.org/images/OME-TIFF/2016-06/tubhiswt-3D.zip")

# %%
with zipfile.ZipFile(fn) as zip:
    for name in zip.namelist():
        with open(os.path.basename(name), "wb") as fo:
            fo.write(zip.read(name))

# %%
reader = ome_files.OMETIFFReader()
reader.set_id("tubhiswt_C0.ome.tif")
pixels = reader.open_array(0)
plt.imshow(pixels, cmap="gray")
reader.close()
